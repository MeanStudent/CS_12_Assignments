# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from keras import layers
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')
import collections
import keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from keras import initializers
from keras.datasets import mnist
from tensorflow import keras
import tensorflow as tf
import itertools
from keras import backend as K
import time
sed = 2022

# %% [markdown]
# # Problem 1 ------ Perceptron
# ### (1)

# %%
# create function
def generate_data(length,seed):
    np.random.seed(seed)
    x_1 = np.expand_dims(np.random.random(length),axis = 1)
    x_2 = np.expand_dims(np.random.random(length),axis = 1)
    df_1 = pd.DataFrame(np.concatenate([x_1,x_2],axis = 1)).rename({0:'x_1',1:'x_2'},axis = 1)
    df_1['y'] = (df_1['x_1'] > df_1['x_2']).astype(int)
    df_1['y'][df_1['y'] == 0] = -1
    return df_1

def train(df,seed,a,lr,epoch):
    # initialize weights
    np.random.seed(seed)
    w_1 = np.random.rand(1)
    w_2 = np.random.rand(1)
    for e in range(epoch):
        for i in range(len(df)):
            # forward
            y_hat = df.iloc[i,2] * (df.iloc[i,0]*w_1 + df.iloc[i,1]*w_2)
            loss = max(0,a-y_hat)
             # backward
            if loss > 0:
                gradient_w1 = -1 * df.iloc[i,2] * df.iloc[i,0] 
                gradient_w2 = -1 * df.iloc[i,2] * df.iloc[i,1]
                w_1 -= lr * gradient_w1
                w_2 -= lr * gradient_w2
            else:
                pass
             
    def predict_func(x1,x2):
        return 1 if w_1*x1 + w_2*x2 > 0 else -1
    return predict_func, (w_1, w_2)

# %%
# Train model
a = 0
df_1_train = generate_data(20,sed)
preceptron, weights = train(df_1_train,sed,a,0.1,1000)
print(weights)
# get test accuracy
df_1_test = generate_data(1000,sed)
pred = []
for i in range(len(df_1_test)):
    pred.append(preceptron(df_1_test.iloc[i,0],df_1_test.iloc[i,1]))
df_1_result = pd.concat([df_1_test,pd.DataFrame(pred).rename({0:'y_pred'},axis = 1)],axis = 1)
df_1_result['AUC'] = df_1_result['y'] == df_1_result['y_pred']
Auc_count = sum(df_1_result['AUC'])
print('Accuracy for this preceptron is: '+ str(Auc_count/1000))
# Out:
# (array([0.09828205]), array([-0.09308899]))
# Accuracy for this preceptron is: 0.978

# %% [markdown]
# ### (2) hinge loss

# %%
# Train model
a = 1
df_2_train = generate_data(20,sed)
preceptron_2, weights = train(df_2_train,sed,a,0.1,1000)
print(weights)
# get test accuracy
df_2_test = generate_data(1000,sed)
pred = []
for i in range(len(df_2_test)):
    pred.append(preceptron_2(df_2_test.iloc[i,0],df_2_test.iloc[i,1]))
df_2_result = pd.concat([df_2_test,pd.DataFrame(pred).rename({0:'y_pred'},axis = 1)],axis = 1)
df_2_result['AUC'] = df_2_result['y'] == df_2_result['y_pred']
Auc_count = sum(df_2_result['AUC'])
print('Accuracy for this preceptron is: '+ str(Auc_count/1000))
# Out:
# (array([12.80079885]), array([-11.97284392]))
# Accuracy for this preceptron is: 0.971

# %% [markdown]
# ### (3)
#
# - First case gives me a better accuracy.
# - It's because in the first case, we only update the weights when we get a wrong prediction, so that our weights will only update towards a direction to minmize the classfication loss. However in the second case, when $0<y(\bar{W} ·\bar{X}) <1$ even though we get a correct prediction, we still have to adjust our weights and the gradient gained by the hindge loss is not always helpful in the classfication

# %% [markdown]
# ### (4)
# - **When the data set is evenly distributed along and close to the true decision boundary** will we gain a stable result of classification of the same 1000 test instances.

# %% [markdown]
# # Problem 2 ------------ Weight Initialization, Dead Neurons, Leaky ReLU
# ### (1)

# %%
# copy the functions need from the github files
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras import backend as K

from matplotlib import pyplot as plt
from matplotlib import rcParamsDefault


def grid_axes_it(n_plots, n_cols=3, enumerate=False, fig=None):
    """
    Iterate through Axes objects on a grid with n_cols columns and as many
    rows as needed to accommodate n_plots many plots.
    Args:
        n_plots: Number of plots to plot onto figure.
        n_cols: Number of columns to divide the figure into.
        fig: Optional figure reference.
    Yields:
        n_plots many Axes objects on a grid.
    """
    n_rows = n_plots / n_cols + int(n_plots % n_cols > 0)

    if not fig:
        default_figsize = rcParamsDefault['figure.figsize']
        fig = plt.figure(figsize=(
            default_figsize[0] * n_cols,
            default_figsize[1] * n_rows
        ))

    for i in range(1, n_plots + 1):
        ax = plt.subplot(n_rows, n_cols, i)
        yield ax


def create_mlp_model(
    n_hidden_layers,
    dim_layer,
    input_shape,
    n_classes,
    kernel_initializer,
    bias_initializer,
    activation,
):
    """Create Multi-Layer Perceptron with given parameters."""
    model = Sequential()
    model.add(Dense(dim_layer, input_shape=input_shape, kernel_initializer=kernel_initializer,
                    bias_initializer=bias_initializer))
    for i in range(n_hidden_layers):
        model.add(Dense(dim_layer, activation=activation, kernel_initializer=kernel_initializer,
                        bias_initializer=bias_initializer))
    model.add(Dense(n_classes, activation='softmax', kernel_initializer=kernel_initializer,
                    bias_initializer=bias_initializer))
    return model


def create_cnn_model(input_shape, num_classes, kernel_initializer='glorot_uniform',
                     bias_initializer='zeros'):
    """Create CNN model similar to
       https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py."""
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=input_shape,
                     kernel_initializer=kernel_initializer,
                     bias_initializer=bias_initializer))
    model.add(Conv2D(64, (3, 3), activation='relu',
                     kernel_initializer=kernel_initializer,
                     bias_initializer=bias_initializer))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu',
                    kernel_initializer=kernel_initializer,
                    bias_initializer=bias_initializer))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax',
                    kernel_initializer=kernel_initializer,
                    bias_initializer=bias_initializer))
    return model


def compile_model(model):
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=keras.optimizers.RMSprop(),
                  metrics=['accuracy'])
    return model


def get_init_id(init):
    """
    Returns string ID summarizing initialization scheme and its parameters.
    Args:
        init: Instance of some initializer from keras.initializers.
    """
    try:
        init_name = str(init).split('.')[2].split(' ')[0]
    except:
        init_name = str(init).split(' ')[0].replace('.', '_')

    param_list = []
    config = init.get_config()
    for k, v in config.items():
        if k == 'seed':
            continue
        param_list.append('{k}-{v}'.format(k=k, v=v))
    init_params = '__'.join(param_list)

    return '|'.join([init_name, init_params])


def get_activations(model, x, mode=0.0):
    """Extract activations with given model and input vector x."""
    outputs = [layer.output for layer in model.layers]
    activations = K.function([model.input], outputs)
    output_elts = activations([x])
    return output_elts


class LossHistory(keras.callbacks.Callback):
    """A custom keras callback for recording losses during network training."""

    def on_train_begin(self, logs={}):
        self.losses = []
        self.epoch_losses = []
        self.epoch_val_losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))

    def on_epoch_end(self, epoch, logs={}):
        self.epoch_losses.append(logs.get('loss'))
        self.epoch_val_losses.append(logs.get('val_loss'))

# %% [markdown]
# ### Relu Activation

# %%
# copy code from plot_activation_layers.py file

seed = 10

# Number of points to plot
n_train = 1000
n_test = 100
n_classes = 10

# Network params
n_hidden_layers = 5
dim_layer = 100
batch_size = n_train
epochs = 12

# Load and prepare MNIST dataset.
n_train = 60000
n_test = 10000

(x_train, y_train), (x_test, y_test) = mnist.load_data()
num_classes = len(np.unique(y_test))
data_dim = 28 * 28

x_train = x_train.reshape(60000, 784).astype('float32')[:n_train]
x_test = x_test.reshape(10000, 784).astype('float32')[:n_train]
x_train /= 255
x_test /= 255

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Run the data through a few MLP models and save the activations from
# each layer into a Pandas DataFrame.
rows = []
sigmas = [0.01, 0.14, 0.28]
for stddev in sigmas:
    init = initializers.RandomNormal(mean=0.0, stddev=stddev, seed=seed)
    activation = 'relu'

    model = create_mlp_model(
        n_hidden_layers,
        dim_layer,
        (data_dim,),
        n_classes,
        init,
        'zeros',
        activation
    )
    compile_model(model)
    output_elts = get_activations(model, x_test)
    n_layers = len(model.layers)
    i_output_layer = n_layers - 1

    for i, out in enumerate(output_elts[:-1]):
        if i > 0 and i != i_output_layer:
            for out_i in out.ravel()[::20]:
                rows.append([i, stddev, out_i])

df = pd.DataFrame(rows, columns=['Hidden Layer', 'Standard Deviation', 'Output'])

# Plot previously saved activations from the 5 hidden layers
# using different initialization schemes.
fig = plt.figure(figsize=(12, 6))
axes = grid_axes_it(len(sigmas), 1, fig=fig)
for sig in sigmas:
    ax = next(axes)
    ddf = df[df['Standard Deviation'] == sig]
    sns.violinplot(x='Hidden Layer', y='Output', data=ddf, ax=ax, scale='count', inner=None)

    ax.set_xlabel('')
    ax.set_ylabel('')

    ax.set_title('Weights Drawn from $N(\mu = 0, \sigma = {%.2f})$' % sig, fontsize=13)

    if sig == sigmas[1]:
        ax.set_ylabel("ReLu Neuron Outputs")
    if sig != sigmas[-1]:
        ax.set_xticklabels(())
    else:
        ax.set_xlabel("Hidden Layer")

plt.tight_layout()
plt.show()
# Out:
# 2022-10-11 23:17:21.761996: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### sigmoid activation

# %%
sigmas = [0.01, 0.14, 0.28]
for stddev in sigmas:
    init = initializers.RandomNormal(mean=0.0, stddev=stddev, seed=seed)
    activation = 'sigmoid'

    model = create_mlp_model(
        n_hidden_layers,
        dim_layer,
        (data_dim,),
        n_classes,
        init,
        'zeros',
        activation
    )
    compile_model(model)
    output_elts = get_activations(model, x_test)
    n_layers = len(model.layers)
    i_output_layer = n_layers - 1

    for i, out in enumerate(output_elts[:-1]):
        if i > 0 and i != i_output_layer:
            for out_i in out.ravel()[::20]:
                rows.append([i, stddev, out_i])

df = pd.DataFrame(rows, columns=['Hidden Layer', 'Standard Deviation', 'Output'])

# Plot previously saved activations from the 5 hidden layers
# using different initialization schemes.
fig = plt.figure(figsize=(12, 6))
axes = grid_axes_it(len(sigmas), 1, fig=fig)
for sig in sigmas:
    ax = next(axes)
    ddf = df[df['Standard Deviation'] == sig]
    sns.violinplot(x='Hidden Layer', y='Output', data=ddf, ax=ax, scale='count', inner=None)

    ax.set_xlabel('')
    ax.set_ylabel('')

    ax.set_title('Weights Drawn from $N(\mu = 0, \sigma = {%.2f})$' % sig, fontsize=13)

    if sig == sigmas[1]:
        ax.set_ylabel("Sigmoid Neuron Outputs")
    if sig != sigmas[-1]:
        ax.set_xticklabels(())
    else:
        ax.set_xlabel("Hidden Layer")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tanh activation

# %%
sigmas = [0.01, 0.14, 0.28]
for stddev in sigmas:
    init = initializers.RandomNormal(mean=0.0, stddev=stddev, seed=seed)
    activation = 'tanh'

    model = create_mlp_model(
        n_hidden_layers,
        dim_layer,
        (data_dim,),
        n_classes,
        init,
        'zeros',
        activation
    )
    compile_model(model)
    output_elts = get_activations(model, x_test)
    n_layers = len(model.layers)
    i_output_layer = n_layers - 1

    for i, out in enumerate(output_elts[:-1]):
        if i > 0 and i != i_output_layer:
            for out_i in out.ravel()[::20]:
                rows.append([i, stddev, out_i])

df = pd.DataFrame(rows, columns=['Hidden Layer', 'Standard Deviation', 'Output'])

# Plot previously saved activations from the 5 hidden layers
# using different initialization schemes.
fig = plt.figure(figsize=(12, 6))
axes = grid_axes_it(len(sigmas), 1, fig=fig)
for sig in sigmas:
    ax = next(axes)
    ddf = df[df['Standard Deviation'] == sig]
    sns.violinplot(x='Hidden Layer', y='Output', data=ddf, ax=ax, scale='count', inner=None)

    ax.set_xlabel('')
    ax.set_ylabel('')

    ax.set_title('Weights Drawn from $N(\mu = 0, \sigma = {%.2f})$' % sig, fontsize=13)

    if sig == sigmas[1]:
        ax.set_ylabel("Tanh Neuron Outputs")
    if sig != sigmas[-1]:
        ax.set_xticklabels(())
    else:
        ax.set_xlabel("Hidden Layer")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### GlorotNormal initialization

# %%
sigmas = [0.01, 0.14, 0.28]
for stddev in sigmas:
    init = initializers.glorot_normal(seed = seed)
    activation = 'relu'

    model = create_mlp_model(
        n_hidden_layers,
        dim_layer,
        (data_dim,),
        n_classes,
        init,
        'zeros',
        activation
    )
    compile_model(model)
    output_elts = get_activations(model, x_test)
    n_layers = len(model.layers)
    i_output_layer = n_layers - 1

    for i, out in enumerate(output_elts[:-1]):
        if i > 0 and i != i_output_layer:
            for out_i in out.ravel()[::20]:
                rows.append([i, stddev, out_i])

df = pd.DataFrame(rows, columns=['Hidden Layer', 'Standard Deviation', 'Output'])

# Plot previously saved activations from the 5 hidden layers
# using different initialization schemes.
fig = plt.figure(figsize=(12, 6))
axes = grid_axes_it(len(sigmas), 1, fig=fig)
for sig in sigmas:
    ax = next(axes)
    ddf = df[df['Standard Deviation'] == sig]
    sns.violinplot(x='Hidden Layer', y='Output', data=ddf, ax=ax, scale='count', inner=None)

    ax.set_xlabel('')
    ax.set_ylabel('')

    ax.set_title('Weights Drawn from $N(\mu = 0, \sigma = {%.2f})$' % sig, fontsize=13)

    if sig == sigmas[1]:
        ax.set_ylabel("ReLu Neuron Outputs")
    if sig != sigmas[-1]:
        ax.set_xticklabels(())
    else:
        ax.set_xlabel("Hidden Layer")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### He initialization

# %%
sigmas = [0.01, 0.14, 0.28]
for stddev in sigmas:
    init = initializers.HeNormal(seed=seed)
    activation = 'tanh'

    model = create_mlp_model(
        n_hidden_layers,
        dim_layer,
        (data_dim,),
        n_classes,
        init,
        'zeros',
        activation
    )
    compile_model(model)
    output_elts = get_activations(model, x_test)
    n_layers = len(model.layers)
    i_output_layer = n_layers - 1

    for i, out in enumerate(output_elts[:-1]):
        if i > 0 and i != i_output_layer:
            for out_i in out.ravel()[::20]:
                rows.append([i, stddev, out_i])

df = pd.DataFrame(rows, columns=['Hidden Layer', 'Standard Deviation', 'Output'])

# Plot previously saved activations from the 5 hidden layers
# using different initialization schemes.
fig = plt.figure(figsize=(12, 6))
axes = grid_axes_it(len(sigmas), 1, fig=fig)
for sig in sigmas:
    ax = next(axes)
    ddf = df[df['Standard Deviation'] == sig]
    sns.violinplot(x='Hidden Layer', y='Output', data=ddf, ax=ax, scale='count', inner=None)

    ax.set_xlabel('')
    ax.set_ylabel('')

    ax.set_title('Weights Drawn from $N(\mu = 0, \sigma = {%.2f})$' % sig, fontsize=13)

    if sig == sigmas[1]:
        ax.set_ylabel("ReLu Neuron Outputs")
    if sig != sigmas[-1]:
        ax.set_xticklabels(())
    else:
        ax.set_xlabel("Hidden Layer")

plt.tight_layout()
plt.show()

# %% [markdown]
# - Here in order to see the effect clear I use the $[0.01,0.14,0.28]$ As my sigmas, and as shown on the above plots, as the $\sigma$ close to zero, we will face the Vanishing gradient since for front layers the gradient are close to 0 so that they're not updating.
# - Comparied with relu, using simoid and Tanh is less likly to encounter Vanishing gradient.
# - After change the initializer into GlorotNormal, the Vanishing gradient for relu activation is imporved.
# - After change the initializer into Heinitialization, the Vanishing gradient for relu activation is imporved.

# %% [markdown]
# ### (2)

# %%
collapus_count = 0
for i in range(1000):
    x = np.random.uniform(-np.sqrt(7),np.sqrt(7),3000)
    y = np.abs(x)
    init = initializers.HeNormal(seed = sed)
    model_2 = keras.Sequential([layers.Dense(2, activation="relu",input_shape = (1,),
                                             kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation="relu",kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation="relu",kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation="relu",kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation="relu",kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation="relu",kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation="relu",kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation="relu",kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation="relu",kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation="relu",kernel_initializer=init,use_bias=True),
                             layers.Dense(1,use_bias=False)])
    model_2.compile(loss='mean_squared_error', optimizer='adam', metrics=['MSE'])
    model_2.fit(x=x,y=y, epochs=1, batch_size=64, verbose=0)
    pred = model_2.predict(x)
    if len(np.unique(pred)) == 1 and np.unique(pred)[0]==0:
        collapus_count+=1

# %%
print('The collapsed models are: ' + str(collapus_count)+' ,So the proportion is close to 90% as reported in the paper')
# Out:
# The collapsed models are: 91 ,So the proportion is close to 90% as reported in the paper

# %% [markdown]
# ### (3)

# %%
leakyrelu = tf.keras.layers.LeakyReLU(alpha=0.01)
collapus_count_leak_relu = 0
for i in range(1000):
    x = np.random.uniform(-np.sqrt(7),np.sqrt(7),3000)
    y = np.abs(x)
    init = initializers.HeNormal(seed = sed)
    model_3 = keras.Sequential([layers.Dense(2, activation=leakyrelu,input_shape = (1,),
                                             kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation=leakyrelu,kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation=leakyrelu,kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation=leakyrelu,kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation=leakyrelu,kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation=leakyrelu,kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation=leakyrelu,kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation=leakyrelu,kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation=leakyrelu,kernel_initializer=init,use_bias=True),
                             layers.Dense(2, activation=leakyrelu,kernel_initializer=init,use_bias=True),
                             layers.Dense(1,use_bias=False)])
    model_3.compile(loss='mean_squared_error', optimizer='adam', metrics=['MSE'])
    model_3.fit(x=x,y=y, epochs=1, batch_size=64, verbose=0)
    pred = model_3.predict(x)
    if len(np.unique(pred)) == 1 and np.unique(pred)[0]==0:
        collapus_count_leak_relu+=1

# %%
print('The collapsed models are: ' + str(collapus_count_leak_relu)+' , there is no collapse after using leakeyrelu!')
# Out:
# The collapsed models are: 0 , there is no collapse after using leakeyrelu!

# %% [markdown]
# # Problem 3 ------- Batch Normalization, Dropout, MNIST

# %% [markdown]
# ### (1)
#
# ##### co-adaptation
# - As is stated in Hinton's paper **The ability of a set of genes to be able to work well with another random set of genes makes them more robust. Since a gene cannot rely on a large set of partners to be present at all times, it must learn to do something useful on its own or in collaboration with a small number of other genes.** In the neural network, neurons just works like gene in sexual reproduction. When adding dropout, the complex co-adaptation is reduced thus making neural network more robust and have better performance on test datasets.
#
# ##### covariance-shift
# -  Covariance-shift is defined as **the distribution of each layer’s inputs changes during training, as the parameters of the previous layers change.**. However by using the regularization like Batch Normalization, we can actually let input of each layer transform into standard normal distribution, thus let all hidden layers have the same distribution of input, and address the covariance-shift problem.

# %% [markdown]
# ### (2)

# %%
# preprocess data
(x_train, y_train), (x_val, y_val) = mnist.load_data()
x_train = np.expand_dims(x_train, axis = 3)
x_val = np.expand_dims(x_val, axis = 3)
mean_train = np.mean(x_train)
var_train = np.var(x_train)

# define Lenet-5 and add BNlayer and train the model
model_3_2 = tf.keras.models.Sequential([
        tf.keras.layers.Normalization(axis=-1, mean=mean_train, variance=var_train),
        tf.keras.layers.Conv2D(6, kernel_size=5, strides = 1,input_shape = (28,28,1),activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.AveragePooling2D(pool_size =(2,2), strides = 2),
        tf.keras.layers.Conv2D(16, kernel_size = 5, strides = 1, activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.AveragePooling2D(pool_size = (2,2), strides = 2),
        tf.keras.layers.Conv2D(120, kernel_size = 2, strides = 2, activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(84, activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(10, activation = 'softmax'),
    ])

model_3_2.compile(loss = 'sparse_categorical_crossentropy',optimizer = 'adam', metrics = ['accuracy'])
history_3_2 = model_3_2.fit(x_train, y_train, epochs = 10, batch_size = 64, validation_data=(x_val, y_val))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 14s 14ms/step - loss: 0.1688 - accuracy: 0.9500 - val_loss: 0.0709 - val_accuracy: 0.9774
# Epoch 2/10
# 938/938 [==============================] - 13s 14ms/step - loss: 0.0634 - accuracy: 0.9811 - val_loss: 0.0531 - val_accuracy: 0.9806
# Epoch 3/10
# 938/938 [==============================] - 13s 14ms/step - loss: 0.0472 - accuracy: 0.9852 - val_loss: 0.0480 - val_accuracy: 0.9851
# Epoch 4/10
# 938/938 [==============================] - 13s 14ms/step - loss: 0.0419 - accuracy: 0.9870 - val_loss: 0.0412 - val_accuracy: 0.9863
# Epoch 5/10
# 938/938 [==============================] - 13s 14ms/step - loss: 0.0369 - accuracy: 0.9882 - val_loss: 0.0383 - val_accuracy: 0.9871
# Epoch 6/10
# 938/938 [==============================] - 13s 14ms/step - loss: 0.0332 - accuracy: 0.9890 - val_loss: 0.0347 - val_accuracy: 0.9885
# Epoch 7/10
# 938/938 [==============================] - 14s 14ms/step - loss: 0.0302 - accuracy: 0.9905 - val_loss: 0.0460 - val_accuracy: 0.9843
# Epoch 8/10
# 938/938 [==============================] - 14s 14ms/step - loss: 0.0281 - accuracy: 0.9909 - val_loss: 0.0311 - val_accuracy: 0.9898
# Epoch 9/10
# 938/938 [==============================] - 13s 14ms/step - loss: 0.0255 - accuracy: 0.9917 - val_loss: 0.0347 - val_accuracy: 0.9879
# Epoch 10/10
# 938/938 [==============================] - 13s 14ms/step - loss: 0.0246 - accuracy: 0.9923 - val_loss: 0.0358 - val_accuracy: 0.9893

# %%
# get parametres in BN_layer
BN_index = [2,5,8,11]
BN_parameters_df = None
BN_index_count = 0
for i in BN_index:
    weight = model_3_2.layers[i].get_weights()
    weight = np.concatenate(weight)
    index = BN_index_count*np.ones_like(weight)
    weight = np.expand_dims(weight,axis = 1)
    index = np.expand_dims(index,axis = 1)
    weight = np.concatenate([weight,index],axis = 1)
    weight = pd.DataFrame(weight)
    BN_index_count+=1
    if BN_parameters_df is not None:
        BN_parameters_df = pd.concat([BN_parameters_df,weight],axis = 0)
    else:
        BN_parameters_df = weight
BN_parameters_df = BN_parameters_df.rename({0:'weights',1:'BN_layer_index'},axis = 1)
sns.violinplot(x = BN_parameters_df['BN_layer_index'], 
               y = BN_parameters_df['weights']).set(title = 'Std_norm_input + BN_hidden')
# Out:
# [Text(0.5, 1.0, 'Std_norm_input + BN_hidden')]

# %% [markdown]
# ### (3)

# %%
# define Lenet-5 and add BNlayer and train the model
model_3_3 = tf.keras.models.Sequential([
        tf.keras.layers.BatchNormalization(input_shape = (28,28,1)),
        tf.keras.layers.Conv2D(6, kernel_size=5, strides = 1,activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.AveragePooling2D(pool_size =(2,2), strides = 2),
        tf.keras.layers.Conv2D(16, kernel_size = 5, strides = 1, activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.AveragePooling2D(pool_size = (2,2), strides = 2),
        tf.keras.layers.Conv2D(120, kernel_size = 2, strides = 2, activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(84, activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(10, activation = 'softmax'),
    ])

model_3_3.compile(loss = 'sparse_categorical_crossentropy',optimizer = 'adam', metrics = ['accuracy'])
history_3_3 = model_3_3.fit(x_train, y_train, epochs = 10, batch_size = 64, validation_data=(x_val, y_val))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 16s 16ms/step - loss: 0.1576 - accuracy: 0.9532 - val_loss: 0.0611 - val_accuracy: 0.9808
# Epoch 2/10
# 938/938 [==============================] - 15s 16ms/step - loss: 0.0620 - accuracy: 0.9808 - val_loss: 0.0448 - val_accuracy: 0.9850
# Epoch 3/10
# 938/938 [==============================] - 15s 16ms/step - loss: 0.0471 - accuracy: 0.9853 - val_loss: 0.0425 - val_accuracy: 0.9867
# Epoch 4/10
# 938/938 [==============================] - 15s 16ms/step - loss: 0.0404 - accuracy: 0.9873 - val_loss: 0.0416 - val_accuracy: 0.9861
# Epoch 5/10
# 938/938 [==============================] - 15s 16ms/step - loss: 0.0343 - accuracy: 0.9893 - val_loss: 0.0411 - val_accuracy: 0.9885
# Epoch 6/10
# 938/938 [==============================] - 15s 16ms/step - loss: 0.0321 - accuracy: 0.9895 - val_loss: 0.0336 - val_accuracy: 0.9898
# Epoch 7/10
# 938/938 [==============================] - 15s 16ms/step - loss: 0.0296 - accuracy: 0.9907 - val_loss: 0.0411 - val_accuracy: 0.9867
# Epoch 8/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0253 - accuracy: 0.9919 - val_loss: 0.0546 - val_accuracy: 0.9837
# Epoch 9/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0233 - accuracy: 0.9924 - val_loss: 0.0393 - val_accuracy: 0.9891
# Epoch 10/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.0392 - val_accuracy: 0.9866

# %%
BN_index = [0,2,5,8,11]
BN_parameters_df = None
BN_index_count = 0
for i in BN_index:
    weight = model_3_3.layers[i].get_weights()
    weight = np.concatenate(weight)
    index = BN_index_count*np.ones_like(weight)
    weight = np.expand_dims(weight,axis = 1)
    index = np.expand_dims(index,axis = 1)
    weight = np.concatenate([weight,index],axis = 1)
    weight = pd.DataFrame(weight)
    BN_index_count+=1
    if BN_parameters_df is not None:
        BN_parameters_df = pd.concat([BN_parameters_df,weight],axis = 0)
    else:
        BN_parameters_df = weight
BN_parameters_df = BN_parameters_df.rename({0:'weights',1:'BN_layer_index'},axis = 1)
sns.violinplot(x = BN_parameters_df['BN_layer_index'], 
               y = BN_parameters_df['weights']).set(title = 'All_BN')
# Out:
# [Text(0.5, 1.0, 'All_BN')]

# %% [markdown]
# ##### compare train/test loss

# %%
fig, ax = plt.subplots(1,2,figsize = (10,5))
epoch_plot = range(10)
for key in history_3_2.history.keys():
    ax[0].plot(epoch_plot,history_3_2.history[key],label = key)
    ax[0].legend()
    ax[0].set_title('Std_norm_input_training')
    
for key in history_3_3.history.keys():
    ax[1].plot(epoch_plot,history_3_3.history[key],label = key)
    ax[1].legend()
    ax[1].set_title('BN_input_training')

# %% [markdown]
# - According to the plot, using the BN for input didn't improve the performace significantly, on the contrary, it slightly increase the validation_loss a little bit on the 7th epoch. And also, according to the violinplot the parameters in BN layer of input and hidden layer are not in the same scale.

# %% [markdown]
# ### (4)

# %%
# define Lenet-5 and add BNlayer and train the model
model_3_4 = tf.keras.models.Sequential([
        tf.keras.layers.Dropout(0.2,input_shape = (28,28,1)),
        tf.keras.layers.Conv2D(6, kernel_size=5, strides = 1,activation = 'tanh'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.AveragePooling2D(pool_size =(2,2), strides = 2),
        tf.keras.layers.Conv2D(16, kernel_size = 5, strides = 1, activation = 'tanh'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.AveragePooling2D(pool_size = (2,2), strides = 2),
        tf.keras.layers.Conv2D(120, kernel_size = 2, strides = 2, activation = 'tanh'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(84, activation = 'tanh'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation = 'softmax'),
    ])

model_3_4.compile(loss = 'sparse_categorical_crossentropy',optimizer = 'adam', metrics = ['accuracy'])
history_3_4 = model_3_3.fit(x_train, y_train, epochs = 10, batch_size = 64, validation_data=(x_val, y_val))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0379 - val_accuracy: 0.9901
# Epoch 2/10
# 938/938 [==============================] - 15s 16ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0403 - val_accuracy: 0.9881
# Epoch 3/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0420 - val_accuracy: 0.9898
# Epoch 4/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0096 - accuracy: 0.9967 - val_loss: 0.0376 - val_accuracy: 0.9896
# Epoch 5/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.0434 - val_accuracy: 0.9895
# Epoch 6/10
# 938/938 [==============================] - 17s 18ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0402 - val_accuracy: 0.9894
# Epoch 7/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.0367 - val_accuracy: 0.9900
# Epoch 8/10
# 938/938 [==============================] - 15s 16ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0358 - val_accuracy: 0.9903
# Epoch 9/10
# 938/938 [==============================] - 15s 16ms/step - loss: 0.0067 - accuracy: 0.9976 - val_loss: 0.0350 - val_accuracy: 0.9897
# Epoch 10/10
# 938/938 [==============================] - 15s 16ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.0345 - val_accuracy: 0.9913

# %%
fig, ax = plt.subplots(1,3,figsize = (15,5))
epoch_plot = range(10)
for key in history_3_2.history.keys():
    ax[0].plot(epoch_plot,history_3_2.history[key],label = key)
    ax[0].legend()
    ax[0].set_title('Std_norm_input_training')
    
for key in history_3_3.history.keys():
    ax[1].plot(epoch_plot,history_3_3.history[key],label = key)
    ax[1].legend()
    ax[1].set_title('BN_input_training')
    
for key in history_3_4.history.keys():
    ax[2].plot(epoch_plot,history_3_4.history[key],label = key)
    ax[2].legend()
    ax[2].set_title('Drop_out_training')

# %% [markdown]
# - After using Dropout layer instead of BN layer, the model converged within one epoch, it trained faster, but the final accuracy and loss seems don't have a significant difference.

# %% [markdown]
# ### (5)

# %%
model_3_5 = tf.keras.models.Sequential([
        tf.keras.layers.BatchNormalization(input_shape = (28,28,1)),
        tf.keras.layers.Conv2D(6, kernel_size=5, strides = 1,activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.AveragePooling2D(pool_size =(2,2), strides = 2),
        tf.keras.layers.Conv2D(16, kernel_size = 5, strides = 1, activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.AveragePooling2D(pool_size = (2,2), strides = 2),
        tf.keras.layers.Conv2D(120, kernel_size = 2, strides = 2, activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(84, activation = 'tanh'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation = 'softmax'),
    ])

model_3_5.compile(loss = 'sparse_categorical_crossentropy',optimizer = 'adam', metrics = ['accuracy'])
history_3_5 = model_3_5.fit(x_train, y_train, epochs = 10, batch_size = 64, validation_data=(x_val, y_val))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 17s 17ms/step - loss: 0.5908 - accuracy: 0.8151 - val_loss: 0.1129 - val_accuracy: 0.9642
# Epoch 2/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2424 - accuracy: 0.9269 - val_loss: 0.0771 - val_accuracy: 0.9751
# Epoch 3/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1970 - accuracy: 0.9407 - val_loss: 0.0607 - val_accuracy: 0.9798
# Epoch 4/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1780 - accuracy: 0.9477 - val_loss: 0.0539 - val_accuracy: 0.9828
# Epoch 5/10
# 938/938 [==============================] - 20s 22ms/step - loss: 0.1633 - accuracy: 0.9516 - val_loss: 0.0552 - val_accuracy: 0.9830
# Epoch 6/10
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1535 - accuracy: 0.9547 - val_loss: 0.0536 - val_accuracy: 0.9821
# Epoch 7/10
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1491 - accuracy: 0.9556 - val_loss: 0.0489 - val_accuracy: 0.9848
# Epoch 8/10
# 938/938 [==============================] - 17s 18ms/step - loss: 0.1446 - accuracy: 0.9579 - val_loss: 0.0492 - val_accuracy: 0.9836
# Epoch 9/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1376 - accuracy: 0.9600 - val_loss: 0.0414 - val_accuracy: 0.9861
# Epoch 10/10
# 938/938 [==============================] - 16s 17ms/step - loss: 0.1326 - accuracy: 0.9605 - val_loss: 0.0436 - val_accuracy: 0.9850

# %%
fig, ax = plt.subplots(1,4,figsize = (20,5))
epoch_plot = range(10)
for key in history_3_2.history.keys():
    ax[0].plot(epoch_plot,history_3_2.history[key],label = key)
    ax[0].legend()
    ax[0].set_title('Std_norm_input_training')
    
for key in history_3_3.history.keys():
    ax[1].plot(epoch_plot,history_3_3.history[key],label = key)
    ax[1].legend()
    ax[1].set_title('BN_input_training')
    
for key in history_3_4.history.keys():
    ax[2].plot(epoch_plot,history_3_4.history[key],label = key)
    ax[2].legend()
    ax[2].set_title('Drop_out_training')
    
for key in history_3_5.history.keys():
    ax[3].plot(epoch_plot,history_3_5.history[key],label = key)
    ax[3].legend()
    ax[3].set_title('Mixed_training')

# %% [markdown]
# - According to the above plot, After using BN and drop togather, model significantly reduces it's performance.

# %% [markdown]
# # Problem 4

# %%
# useful functions and generate data set
def eggholderfx(x_1,x_2):
    part_1 = -(x_2+47)*np.sin(np.sqrt(np.abs(x_1/2 + (x_2+47))))
    part_2 = - x_1*np.sin(np.sqrt(np.abs(x_1-(x_2+47))))
    return  part_1 + part_2
def creat_y(x_1,x_2):
    return (eggholderfx(x_1,x_2) + np.random.normal(loc = 0, scale = np.sqrt(0.3)))
np.random.seed(sed)
X = np.random.uniform(-512,512,(100000,2))
y = []
for i in X:
    x_i = creat_y(i[0],i[1])
    y.append(x_i)
y = np.array(y)

x_train, x_val, y_train, y_val = train_test_split(X,y,test_size=0.2, random_state=sed)

# %% [markdown]
# ### (1)

# %%
unit_selection = [16,32,64,128,256,512]
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))
def get_layer_and_units(layer_num,unit_list):
    return_list = []
    for i in itertools.product(unit_list,repeat = layer_num):
        if sum(i) <= 512:
            return_list.append(i)
    return(return_list)

def my_create_model(unit_list):
    model = keras.models.Sequential([keras.layers.Dense(unit_list[0], input_shape = (2,),activation = 'relu')])
    for i,unit in enumerate(unit_list):
        if i != 0:
            model.add(keras.layers.Dense(unit, activation = 'relu'))
    model.add(keras.layers.Dense(1))
    return model

# %%
one_layer = get_layer_and_units(1,unit_selection)
two_layer = get_layer_and_units(2,unit_selection)
three_layer = get_layer_and_units(3,unit_selection)

# %%
# start training one layer model
epoch_num = 10
num_of_units_one_layer = []
rmses_one_layer = []
num_parameters_one_layer = []
used_time_onelayer = []
for i in range(len(two_layer)):  # change layer parameters here
    model =  my_create_model(two_layer[i]) # change layer parameters here
    model.compile(loss = root_mean_squared_error,
                  optimizer = 'adam',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    
    start = time.monotonic()
    model.fit(x_train, y_train, epochs=epoch_num,batch_size = 1000, 
              validation_data=(x_val,y_val),verbose = 0)
    end = time.monotonic()
    total_time = end-start
    rmse = np.sqrt(np.mean(np.power((model.predict(x_val).reshape(len(y_val))-y_val),2)))
    
    used_time_onelayer.append(total_time)
    rmses_one_layer.append(rmse)
    num_of_units_one_layer.append(sum(two_layer[i]))  # change layer parameters here
    num_parameters_one_layer.append(model.count_params())

# %%
used_time_onelayer
# Out:
# [1.032748087996879,
#  1.143238732998725,
#  1.2408131030024379,
#  1.299699592997058,
#  1.4325311980028346,
#  1.0888068299973384,
#  1.1683749049989274,
#  1.2283626349999395,
#  1.2874236419993395,
#  1.9916547510001692,
#  1.219262054997671,
#  2.1049181110029167,
#  1.2590825379993476,
#  1.641753912997956,
#  2.2461458329999004,
#  1.2642782379989512,
#  1.2894799179994152,
#  1.515516513998591,
#  1.6792786699988937,
#  1.6825363040006778,
#  1.3625990870023088,
#  1.525711786998727,
#  1.8309236399982183,
#  1.6612386140004674,
#  1.9705071520002093]

# %%
num_of_units_one_layer
# Out:
# [32,
#  48,
#  80,
#  144,
#  272,
#  48,
#  64,
#  96,
#  160,
#  288,
#  80,
#  96,
#  128,
#  192,
#  320,
#  144,
#  160,
#  192,
#  256,
#  384,
#  272,
#  288,
#  320,
#  384,
#  512]

# %%
rmses_one_layer
# Out:
# [293.28562707175126,
#  292.62993605085944,
#  293.32819815028085,
#  291.6218979232742,
#  289.9721922787571,
#  293.9894600074799,
#  292.10219406223666,
#  290.6774307290013,
#  289.2779924576522,
#  289.2985454384197,
#  292.84013450437607,
#  290.84520149361754,
#  289.99159360484384,
#  288.77413711614906,
#  288.37757393336346,
#  290.4332809312215,
#  290.77682070478255,
#  289.9238205900893,
#  287.8488517260473,
#  287.59093186652393,
#  292.7816457132526,
#  289.3879115553247,
#  289.2261332382976,
#  289.63925118266593,
#  287.24261161390797]

# %%
num_parameters_one_layer
# Out:
# [337,
#  625,
#  1201,
#  2353,
#  4657,
#  641,
#  1185,
#  2273,
#  4449,
#  8801,
#  1249,
#  2305,
#  4417,
#  8641,
#  17089,
#  2465,
#  4545,
#  8705,
#  17025,
#  33665,
#  4897,
#  9025,
#  17281,
#  33793,
#  66817]

# %%
model.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_69 (Dense)            (None, 512)               1536
#
#  dense_70 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 2,049
# Trainable params: 2,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,batch_size = 1000,epochs = 2000 )
# Out:
# Epoch 1/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 249.5386 - root_mean_squared_error: 251.4003
# Epoch 2/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 212.9778 - root_mean_squared_error: 213.0944
# Epoch 3/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 203.6914 - root_mean_squared_error: 203.7614
# Epoch 4/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 198.7728 - root_mean_squared_error: 198.8575
# Epoch 5/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 195.4331 - root_mean_squared_error: 195.5092
# Epoch 6/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 193.4796 - root_mean_squared_error: 193.5575
# Epoch 7/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 189.6243 - root_mean_squared_error: 189.6883
# Epoch 8/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 189.2980 - root_mean_squared_error: 189.3673
# Epoch 9/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 186.5518 - root_mean_squared_error: 186.6227
# Epoch 10/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 186.0596 - root_mean_squared_error: 186.1097
# Epoch 11/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 183.9536 - root_mean_squared_error: 184.0268
# Epoch 12/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 183.1323 - root_mean_squared_error: 183.1953
# Epoch 13/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 182.0521 - root_mean_squared_error: 182.1207
# Epoch 14/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 180.7677 - root_mean_squared_error: 180.8145
# Epoch 15/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 179.7823 - root_mean_squared_error: 179.8296
# Epoch 16/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 177.6787 - root_mean_squared_error: 177.7255
# Epoch 17/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 177.6790 - root_mean_squared_error: 177.7493
# Epoch 18/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 177.0848 - root_mean_squared_error: 177.1669
# Epoch 19/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 175.1434 - root_mean_squared_error: 175.1892
# Epoch 20/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 174.2676 - root_mean_squared_error: 174.3298
# Epoch 21/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 173.4115 - root_mean_squared_error: 173.4734
# Epoch 22/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 172.8995 - root_mean_squared_error: 172.9546
# Epoch 23/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 172.0323 - root_mean_squared_error: 172.0824
# Epoch 24/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 172.1032 - root_mean_squared_error: 172.1555
# Epoch 25/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 171.4205 - root_mean_squared_error: 171.4869
# Epoch 26/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 169.2038 - root_mean_squared_error: 169.2689
# Epoch 27/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 169.1670 - root_mean_squared_error: 169.2261
# Epoch 28/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 168.5342 - root_mean_squared_error: 168.5950
# Epoch 29/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 168.2663 - root_mean_squared_error: 168.3258
# Epoch 30/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 166.5900 - root_mean_squared_error: 166.6375
# Epoch 31/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 166.5944 - root_mean_squared_error: 166.6425
# Epoch 32/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 165.4750 - root_mean_squared_error: 165.5393
# Epoch 33/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 165.4718 - root_mean_squared_error: 165.5327
# Epoch 34/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 165.1762 - root_mean_squared_error: 165.2395
# Epoch 35/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 164.2332 - root_mean_squared_error: 164.2880
# Epoch 36/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 163.4674 - root_mean_squared_error: 163.5190
# Epoch 37/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 162.5002 - root_mean_squared_error: 162.5490
# Epoch 38/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 162.7967 - root_mean_squared_error: 162.8456
# Epoch 39/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 162.5229 - root_mean_squared_error: 162.5588
# Epoch 40/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 162.2198 - root_mean_squared_error: 162.2858
# Epoch 41/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 161.6870 - root_mean_squared_error: 161.7428
# Epoch 42/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 161.4877 - root_mean_squared_error: 161.5499
# Epoch 43/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 161.1067 - root_mean_squared_error: 161.1628
# Epoch 44/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 160.0772 - root_mean_squared_error: 160.1266
# Epoch 45/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 159.6070 - root_mean_squared_error: 159.6626
# Epoch 46/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 159.0375 - root_mean_squared_error: 159.0998
# Epoch 47/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 159.5191 - root_mean_squared_error: 159.5708
# Epoch 48/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 159.8330 - root_mean_squared_error: 159.8910
# Epoch 49/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 159.2521 - root_mean_squared_error: 159.2983
# Epoch 50/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 157.7460 - root_mean_squared_error: 157.8154
# Epoch 51/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 157.7694 - root_mean_squared_error: 157.8274
# Epoch 52/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 157.0566 - root_mean_squared_error: 157.1144
# Epoch 53/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 156.2167 - root_mean_squared_error: 156.2711
# Epoch 54/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 156.3104 - root_mean_squared_error: 156.3905
# Epoch 55/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 156.1604 - root_mean_squared_error: 156.2145
# Epoch 56/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 157.0537 - root_mean_squared_error: 157.1163
# Epoch 57/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 154.9542 - root_mean_squared_error: 155.0196
# Epoch 58/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 155.2664 - root_mean_squared_error: 155.3081
# Epoch 59/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 154.4753 - root_mean_squared_error: 154.5431
# Epoch 60/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 155.0568 - root_mean_squared_error: 155.1080
# Epoch 61/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 153.8176 - root_mean_squared_error: 153.8761
# Epoch 62/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 153.3139 - root_mean_squared_error: 153.4013
# Epoch 63/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 153.6665 - root_mean_squared_error: 153.7226
# Epoch 64/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 152.7411 - root_mean_squared_error: 152.8102
# Epoch 65/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 152.0186 - root_mean_squared_error: 152.0703
# Epoch 66/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 152.1006 - root_mean_squared_error: 152.1764
# Epoch 67/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 151.0423 - root_mean_squared_error: 151.1161
# Epoch 68/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 151.7148 - root_mean_squared_error: 151.7724
# Epoch 69/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 150.4464 - root_mean_squared_error: 150.5196
# Epoch 70/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 151.3321 - root_mean_squared_error: 151.4059
# Epoch 71/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 149.1622 - root_mean_squared_error: 149.2255
# Epoch 72/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 150.0465 - root_mean_squared_error: 150.1023
# Epoch 73/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 149.7706 - root_mean_squared_error: 149.8340
# Epoch 74/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 149.8699 - root_mean_squared_error: 149.9506
# Epoch 75/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 148.5189 - root_mean_squared_error: 148.5666
# Epoch 76/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 147.8906 - root_mean_squared_error: 147.9592
# Epoch 77/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 149.4651 - root_mean_squared_error: 149.5559
# Epoch 78/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 147.7531 - root_mean_squared_error: 147.7984
# Epoch 79/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 148.0338 - root_mean_squared_error: 148.0976
# Epoch 80/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 147.2228 - root_mean_squared_error: 147.2879
# Epoch 81/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 146.6535 - root_mean_squared_error: 146.7112
# Epoch 82/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 146.4172 - root_mean_squared_error: 146.4890
# Epoch 83/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 146.5316 - root_mean_squared_error: 146.5883
# Epoch 84/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 145.7227 - root_mean_squared_error: 145.8107
# Epoch 85/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 146.6501 - root_mean_squared_error: 146.7254
# Epoch 86/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 146.0717 - root_mean_squared_error: 146.1502
# Epoch 87/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 145.3319 - root_mean_squared_error: 145.3986
# Epoch 88/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 145.0092 - root_mean_squared_error: 145.0657
# Epoch 89/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 144.4533 - root_mean_squared_error: 144.5331
# Epoch 90/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 144.2239 - root_mean_squared_error: 144.2905
# Epoch 91/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 143.4078 - root_mean_squared_error: 143.4590
# Epoch 92/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 143.7858 - root_mean_squared_error: 143.8489
# Epoch 93/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 143.4568 - root_mean_squared_error: 143.5154
# Epoch 94/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 142.7453 - root_mean_squared_error: 142.8133
# Epoch 95/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 143.3759 - root_mean_squared_error: 143.4342
# Epoch 96/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 141.7311 - root_mean_squared_error: 141.7938
# Epoch 97/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 141.8887 - root_mean_squared_error: 141.9496
# Epoch 98/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 141.5596 - root_mean_squared_error: 141.6247
# Epoch 99/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 142.0392 - root_mean_squared_error: 142.0899
# Epoch 100/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 141.2080 - root_mean_squared_error: 141.2833
# Epoch 101/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 140.8229 - root_mean_squared_error: 140.8813
# Epoch 102/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 140.2847 - root_mean_squared_error: 140.3635
# Epoch 103/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 140.6590 - root_mean_squared_error: 140.7425
# Epoch 104/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 140.2584 - root_mean_squared_error: 140.3289
# Epoch 105/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 139.5835 - root_mean_squared_error: 139.6518
# Epoch 106/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 138.7961 - root_mean_squared_error: 138.8581
# Epoch 107/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 139.4130 - root_mean_squared_error: 139.4753
# Epoch 108/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 140.7134 - root_mean_squared_error: 140.7766
# Epoch 109/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 139.7617 - root_mean_squared_error: 139.8226
# Epoch 110/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 138.6250 - root_mean_squared_error: 138.7072
# Epoch 111/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 138.3638 - root_mean_squared_error: 138.4274
# Epoch 112/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 138.1516 - root_mean_squared_error: 138.2231
# Epoch 113/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 138.7350 - root_mean_squared_error: 138.8077
# Epoch 114/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 138.2882 - root_mean_squared_error: 138.3523
# Epoch 115/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 138.4590 - root_mean_squared_error: 138.5288
# Epoch 116/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 137.3750 - root_mean_squared_error: 137.4326
# Epoch 117/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 137.6795 - root_mean_squared_error: 137.7516
# Epoch 118/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 137.1730 - root_mean_squared_error: 137.2452
# Epoch 119/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 136.3022 - root_mean_squared_error: 136.3783
# Epoch 120/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 136.5824 - root_mean_squared_error: 136.6600
# Epoch 121/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 135.5105 - root_mean_squared_error: 135.5772
# Epoch 122/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 136.1858 - root_mean_squared_error: 136.2586
# Epoch 123/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 135.1955 - root_mean_squared_error: 135.2608
# Epoch 124/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 134.9635 - root_mean_squared_error: 135.0174
# Epoch 125/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 134.5092 - root_mean_squared_error: 134.5756
# Epoch 126/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 134.9431 - root_mean_squared_error: 135.0257
# Epoch 127/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 134.6090 - root_mean_squared_error: 134.6767
# Epoch 128/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 134.5410 - root_mean_squared_error: 134.6113
# Epoch 129/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 133.6728 - root_mean_squared_error: 133.7396
# Epoch 130/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 134.1014 - root_mean_squared_error: 134.1875
# Epoch 131/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 133.5402 - root_mean_squared_error: 133.6125
# Epoch 132/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 133.0755 - root_mean_squared_error: 133.1353
# Epoch 133/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 133.3106 - root_mean_squared_error: 133.3741
# Epoch 134/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 132.5699 - root_mean_squared_error: 132.6322
# Epoch 135/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 132.9936 - root_mean_squared_error: 133.0691
# Epoch 136/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 133.5588 - root_mean_squared_error: 133.6310
# Epoch 137/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 132.4016 - root_mean_squared_error: 132.4539
# Epoch 138/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 133.3467 - root_mean_squared_error: 133.4297
# Epoch 139/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 131.5612 - root_mean_squared_error: 131.6314
# Epoch 140/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 131.8114 - root_mean_squared_error: 131.8724
# Epoch 141/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 130.9900 - root_mean_squared_error: 131.0669
# Epoch 142/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 131.4501 - root_mean_squared_error: 131.5048
# Epoch 143/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 131.3845 - root_mean_squared_error: 131.4549
# Epoch 144/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 130.4075 - root_mean_squared_error: 130.4658
# Epoch 145/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 130.3361 - root_mean_squared_error: 130.4134
# Epoch 146/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 130.0289 - root_mean_squared_error: 130.1086
# Epoch 147/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 129.4326 - root_mean_squared_error: 129.5026
# Epoch 148/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 129.2823 - root_mean_squared_error: 129.3465
# Epoch 149/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 129.4350 - root_mean_squared_error: 129.5211
# Epoch 150/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 129.0936 - root_mean_squared_error: 129.1739
# Epoch 151/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 128.7817 - root_mean_squared_error: 128.8339
# Epoch 152/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 129.1075 - root_mean_squared_error: 129.1788
# Epoch 153/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 130.5413 - root_mean_squared_error: 130.6161
# Epoch 154/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 128.8413 - root_mean_squared_error: 128.9067
# Epoch 155/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 128.0678 - root_mean_squared_error: 128.1310
# Epoch 156/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 128.0787 - root_mean_squared_error: 128.1514
# Epoch 157/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 127.3008 - root_mean_squared_error: 127.3831
# Epoch 158/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 128.1557 - root_mean_squared_error: 128.2409
# Epoch 159/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 127.2356 - root_mean_squared_error: 127.3108
# Epoch 160/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 127.9199 - root_mean_squared_error: 128.0034
# Epoch 161/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 127.0058 - root_mean_squared_error: 127.0634
# Epoch 162/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 126.3662 - root_mean_squared_error: 126.4386
# Epoch 163/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 125.7003 - root_mean_squared_error: 125.7690
# Epoch 164/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 126.3514 - root_mean_squared_error: 126.4112
# Epoch 165/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 126.3251 - root_mean_squared_error: 126.3829
# Epoch 166/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 126.7703 - root_mean_squared_error: 126.8363
# Epoch 167/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 124.9991 - root_mean_squared_error: 125.0684
# Epoch 168/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 124.7691 - root_mean_squared_error: 124.8299
# Epoch 169/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 125.7029 - root_mean_squared_error: 125.7880
# Epoch 170/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 125.6231 - root_mean_squared_error: 125.7265
# Epoch 171/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 125.5411 - root_mean_squared_error: 125.6138
# Epoch 172/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 125.0774 - root_mean_squared_error: 125.1537
# Epoch 173/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 124.0892 - root_mean_squared_error: 124.1738
# Epoch 174/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 124.6038 - root_mean_squared_error: 124.6861
# Epoch 175/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 124.6554 - root_mean_squared_error: 124.7345
# Epoch 176/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 124.3212 - root_mean_squared_error: 124.4085
# Epoch 177/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 123.6079 - root_mean_squared_error: 123.6835
# Epoch 178/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 124.2422 - root_mean_squared_error: 124.3127
# Epoch 179/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 123.5824 - root_mean_squared_error: 123.6538
# Epoch 180/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 122.8872 - root_mean_squared_error: 122.9395
# Epoch 181/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 122.4899 - root_mean_squared_error: 122.5542
# Epoch 182/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 122.3345 - root_mean_squared_error: 122.4047
# Epoch 183/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 123.7317 - root_mean_squared_error: 123.8096
# Epoch 184/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 122.9888 - root_mean_squared_error: 123.0625
# Epoch 185/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 121.5869 - root_mean_squared_error: 121.6535
# Epoch 186/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 121.9994 - root_mean_squared_error: 122.0645
# Epoch 187/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 122.0069 - root_mean_squared_error: 122.0905
# Epoch 188/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 122.0114 - root_mean_squared_error: 122.0727
# Epoch 189/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 123.1003 - root_mean_squared_error: 123.1872
# Epoch 190/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 122.6976 - root_mean_squared_error: 122.7843
# Epoch 191/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 121.0636 - root_mean_squared_error: 121.1199
# Epoch 192/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 121.8315 - root_mean_squared_error: 121.8932
# Epoch 193/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 122.9369 - root_mean_squared_error: 123.0280
# Epoch 194/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 121.9557 - root_mean_squared_error: 122.0135
# Epoch 195/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 120.8467 - root_mean_squared_error: 120.9356
# Epoch 196/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 120.7571 - root_mean_squared_error: 120.8114
# Epoch 197/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 120.9977 - root_mean_squared_error: 121.0734
# Epoch 198/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 120.2790 - root_mean_squared_error: 120.3456
# Epoch 199/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 119.7030 - root_mean_squared_error: 119.7800
# Epoch 200/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 120.9128 - root_mean_squared_error: 120.9991
# Epoch 201/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 119.6573 - root_mean_squared_error: 119.7206
# Epoch 202/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 118.8991 - root_mean_squared_error: 118.9617
# Epoch 203/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 119.7013 - root_mean_squared_error: 119.7459
# Epoch 204/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 119.2108 - root_mean_squared_error: 119.2718
# Epoch 205/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 120.9972 - root_mean_squared_error: 121.0862
# Epoch 206/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 119.8519 - root_mean_squared_error: 119.9276
# Epoch 207/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 119.6828 - root_mean_squared_error: 119.7646
# Epoch 208/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 120.6193 - root_mean_squared_error: 120.6838
# Epoch 209/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 118.3961 - root_mean_squared_error: 118.4707
# Epoch 210/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 118.7967 - root_mean_squared_error: 118.8725
# Epoch 211/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 119.7129 - root_mean_squared_error: 119.8074
# Epoch 212/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 120.8313 - root_mean_squared_error: 120.9037
# Epoch 213/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 117.6437 - root_mean_squared_error: 117.7194
# Epoch 214/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 118.4028 - root_mean_squared_error: 118.4575
# Epoch 215/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 117.8696 - root_mean_squared_error: 117.9466
# Epoch 216/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 117.6889 - root_mean_squared_error: 117.7621
# Epoch 217/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 117.5236 - root_mean_squared_error: 117.6056
# Epoch 218/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 119.5958 - root_mean_squared_error: 119.6941
# Epoch 219/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 118.2266 - root_mean_squared_error: 118.2935
# Epoch 220/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 118.2756 - root_mean_squared_error: 118.3642
# Epoch 221/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 118.2599 - root_mean_squared_error: 118.3404
# Epoch 222/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.5515 - root_mean_squared_error: 116.6087
# Epoch 223/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 117.2359 - root_mean_squared_error: 117.2883
# Epoch 224/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 117.7955 - root_mean_squared_error: 117.8734
# Epoch 225/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.7149 - root_mean_squared_error: 116.7783
# Epoch 226/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 117.2452 - root_mean_squared_error: 117.3235
# Epoch 227/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.9067 - root_mean_squared_error: 116.9802
# Epoch 228/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.7060 - root_mean_squared_error: 116.7732
# Epoch 229/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.9196 - root_mean_squared_error: 116.9733
# Epoch 230/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.6421 - root_mean_squared_error: 116.7189
# Epoch 231/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.1021 - root_mean_squared_error: 116.1672
# Epoch 232/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 116.3677 - root_mean_squared_error: 116.4499
# Epoch 233/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.3261 - root_mean_squared_error: 116.4091
# Epoch 234/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.2089 - root_mean_squared_error: 116.2984
# Epoch 235/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 114.8415 - root_mean_squared_error: 114.9269
# Epoch 236/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 114.8587 - root_mean_squared_error: 114.9237
# Epoch 237/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 115.9727 - root_mean_squared_error: 116.0391
# Epoch 238/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 115.0645 - root_mean_squared_error: 115.1304
# Epoch 239/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.0108 - root_mean_squared_error: 116.0584
# Epoch 240/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 115.6970 - root_mean_squared_error: 115.7727
# Epoch 241/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 114.8076 - root_mean_squared_error: 114.8715
# Epoch 242/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 114.7451 - root_mean_squared_error: 114.8063
# Epoch 243/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 114.1639 - root_mean_squared_error: 114.2381
# Epoch 244/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 114.5139 - root_mean_squared_error: 114.5847
# Epoch 245/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 115.5712 - root_mean_squared_error: 115.6511
# Epoch 246/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 116.0567 - root_mean_squared_error: 116.1319
# Epoch 247/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 114.8913 - root_mean_squared_error: 114.9567
# Epoch 248/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 114.4355 - root_mean_squared_error: 114.5101
# Epoch 249/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 115.4012 - root_mean_squared_error: 115.4758
# Epoch 250/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 113.2952 - root_mean_squared_error: 113.3963
# Epoch 251/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 115.0052 - root_mean_squared_error: 115.0772
# Epoch 252/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 115.2734 - root_mean_squared_error: 115.3563
# Epoch 253/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 114.1094 - root_mean_squared_error: 114.1871
# Epoch 254/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 113.7915 - root_mean_squared_error: 113.8640
# Epoch 255/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 113.9929 - root_mean_squared_error: 114.0648
# Epoch 256/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 112.8991 - root_mean_squared_error: 112.9798
# Epoch 257/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 113.8506 - root_mean_squared_error: 113.9348
# Epoch 258/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 113.6677 - root_mean_squared_error: 113.7498
# Epoch 259/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 114.2005 - root_mean_squared_error: 114.2833
# Epoch 260/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 113.6008 - root_mean_squared_error: 113.6980
# Epoch 261/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 113.8332 - root_mean_squared_error: 113.9088
# Epoch 262/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 112.2669 - root_mean_squared_error: 112.3241
# Epoch 263/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 112.1737 - root_mean_squared_error: 112.2434
# Epoch 264/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 112.9324 - root_mean_squared_error: 113.0017
# Epoch 265/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 112.7501 - root_mean_squared_error: 112.8147
# Epoch 266/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 112.5936 - root_mean_squared_error: 112.6572
# Epoch 267/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 111.2386 - root_mean_squared_error: 111.3058
# Epoch 268/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 111.9630 - root_mean_squared_error: 112.0472
# Epoch 269/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 112.1469 - root_mean_squared_error: 112.2716
# Epoch 270/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 111.9892 - root_mean_squared_error: 112.0756
# Epoch 271/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 112.2686 - root_mean_squared_error: 112.3454
# Epoch 272/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 112.2048 - root_mean_squared_error: 112.2833
# Epoch 273/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 111.5182 - root_mean_squared_error: 111.5746
# Epoch 274/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.6109 - root_mean_squared_error: 110.6877
# Epoch 275/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 111.3823 - root_mean_squared_error: 111.4389
# Epoch 276/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 111.4362 - root_mean_squared_error: 111.4957
# Epoch 277/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.4104 - root_mean_squared_error: 110.5016
# Epoch 278/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 111.2634 - root_mean_squared_error: 111.3421
# Epoch 279/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 111.6493 - root_mean_squared_error: 111.7247
# Epoch 280/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.4435 - root_mean_squared_error: 110.4992
# Epoch 281/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.5442 - root_mean_squared_error: 110.6226
# Epoch 282/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.8813 - root_mean_squared_error: 110.9477
# Epoch 283/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.0023 - root_mean_squared_error: 110.0857
# Epoch 284/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.6827 - root_mean_squared_error: 110.7723
# Epoch 285/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 109.5263 - root_mean_squared_error: 109.6127
# Epoch 286/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.4540 - root_mean_squared_error: 110.5435
# Epoch 287/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.9607 - root_mean_squared_error: 109.0423
# Epoch 288/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.5668 - root_mean_squared_error: 110.6454
# Epoch 289/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 109.0602 - root_mean_squared_error: 109.1374
# Epoch 290/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.9660 - root_mean_squared_error: 109.0571
# Epoch 291/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.4724 - root_mean_squared_error: 110.5553
# Epoch 292/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.2731 - root_mean_squared_error: 110.3818
# Epoch 293/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 109.3589 - root_mean_squared_error: 109.4291
# Epoch 294/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 109.2819 - root_mean_squared_error: 109.3656
# Epoch 295/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.0012 - root_mean_squared_error: 110.1018
# Epoch 296/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.2482 - root_mean_squared_error: 108.3317
# Epoch 297/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 110.0608 - root_mean_squared_error: 110.1536
# Epoch 298/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.3509 - root_mean_squared_error: 108.4197
# Epoch 299/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 107.8131 - root_mean_squared_error: 107.8863
# Epoch 300/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.4625 - root_mean_squared_error: 108.5657
# Epoch 301/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.1189 - root_mean_squared_error: 108.1825
# Epoch 302/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.1706 - root_mean_squared_error: 108.2667
# Epoch 303/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.4731 - root_mean_squared_error: 108.5798
# Epoch 304/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 107.9012 - root_mean_squared_error: 107.9791
# Epoch 305/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.3075 - root_mean_squared_error: 108.3746
# Epoch 306/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.3411 - root_mean_squared_error: 108.4154
# Epoch 307/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 108.8319 - root_mean_squared_error: 108.8996
# Epoch 308/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.8361 - root_mean_squared_error: 106.8941
# Epoch 309/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 107.6988 - root_mean_squared_error: 107.7771
# Epoch 310/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.6483 - root_mean_squared_error: 106.7239
# Epoch 311/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 107.1634 - root_mean_squared_error: 107.2494
# Epoch 312/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 107.5796 - root_mean_squared_error: 107.6513
# Epoch 313/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 107.5934 - root_mean_squared_error: 107.6473
# Epoch 314/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.8565 - root_mean_squared_error: 106.9283
# Epoch 315/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.5903 - root_mean_squared_error: 106.6837
# Epoch 316/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.9910 - root_mean_squared_error: 107.0765
# Epoch 317/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.7047 - root_mean_squared_error: 106.7964
# Epoch 318/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.4918 - root_mean_squared_error: 106.5865
# Epoch 319/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 105.6538 - root_mean_squared_error: 105.7134
# Epoch 320/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 105.6268 - root_mean_squared_error: 105.7049
# Epoch 321/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.4565 - root_mean_squared_error: 106.5631
# Epoch 322/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 107.8090 - root_mean_squared_error: 107.8861
# Epoch 323/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 105.2552 - root_mean_squared_error: 105.3306
# Epoch 324/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.3464 - root_mean_squared_error: 106.4371
# Epoch 325/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.0760 - root_mean_squared_error: 106.1656
# Epoch 326/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 104.9619 - root_mean_squared_error: 105.0410
# Epoch 327/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 105.0580 - root_mean_squared_error: 105.1317
# Epoch 328/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 105.6897 - root_mean_squared_error: 105.7724
# Epoch 329/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 106.2253 - root_mean_squared_error: 106.3251
# Epoch 330/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 105.3906 - root_mean_squared_error: 105.4757
# Epoch 331/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 104.8113 - root_mean_squared_error: 104.9060
# Epoch 332/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 104.6796 - root_mean_squared_error: 104.7449
# Epoch 333/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 104.6979 - root_mean_squared_error: 104.7599
# Epoch 334/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 104.8654 - root_mean_squared_error: 104.9543
# Epoch 335/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 104.0435 - root_mean_squared_error: 104.1356
# Epoch 336/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 105.0959 - root_mean_squared_error: 105.1976
# Epoch 337/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 104.3889 - root_mean_squared_error: 104.4733
# Epoch 338/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 104.0865 - root_mean_squared_error: 104.1534
# Epoch 339/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 104.5814 - root_mean_squared_error: 104.6507
# Epoch 340/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 103.4530 - root_mean_squared_error: 103.5494
# Epoch 341/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 103.4970 - root_mean_squared_error: 103.5594
# Epoch 342/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 103.6251 - root_mean_squared_error: 103.7413
# Epoch 343/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 103.2869 - root_mean_squared_error: 103.3738
# Epoch 344/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 102.4607 - root_mean_squared_error: 102.5416
# Epoch 345/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 103.2109 - root_mean_squared_error: 103.3022
# Epoch 346/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 103.1109 - root_mean_squared_error: 103.1908
# Epoch 347/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 103.7648 - root_mean_squared_error: 103.8558
# Epoch 348/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 102.1164 - root_mean_squared_error: 102.1832
# Epoch 349/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 103.0028 - root_mean_squared_error: 103.0964
# Epoch 350/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 101.8419 - root_mean_squared_error: 101.9006
# Epoch 351/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 102.0031 - root_mean_squared_error: 102.0891
# Epoch 352/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 101.5149 - root_mean_squared_error: 101.5887
# Epoch 353/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 101.1657 - root_mean_squared_error: 101.2281
# Epoch 354/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 102.0332 - root_mean_squared_error: 102.1355
# Epoch 355/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 100.4188 - root_mean_squared_error: 100.4940
# Epoch 356/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 100.8129 - root_mean_squared_error: 100.8716
# Epoch 357/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 101.8425 - root_mean_squared_error: 101.9281
# Epoch 358/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 100.3031 - root_mean_squared_error: 100.3621
# Epoch 359/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 99.2466 - root_mean_squared_error: 99.3244
# Epoch 360/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 98.3860 - root_mean_squared_error: 98.4511
# Epoch 361/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 98.7684 - root_mean_squared_error: 98.8589
# Epoch 362/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 98.7248 - root_mean_squared_error: 98.8034
# Epoch 363/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 98.2999 - root_mean_squared_error: 98.3521
# Epoch 364/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 97.4731 - root_mean_squared_error: 97.5480
# Epoch 365/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 99.5816 - root_mean_squared_error: 99.6471
# Epoch 366/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 97.3864 - root_mean_squared_error: 97.4455
# Epoch 367/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 98.1355 - root_mean_squared_error: 98.2167
# Epoch 368/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 97.7183 - root_mean_squared_error: 97.8051
# Epoch 369/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 97.7817 - root_mean_squared_error: 97.8581
# Epoch 370/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 98.7945 - root_mean_squared_error: 98.8761
# Epoch 371/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 98.4063 - root_mean_squared_error: 98.4996
# Epoch 372/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 96.9372 - root_mean_squared_error: 96.9921
# Epoch 373/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 98.0333 - root_mean_squared_error: 98.1009
# Epoch 374/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 96.8042 - root_mean_squared_error: 96.8797
# Epoch 375/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 95.7228 - root_mean_squared_error: 95.7764
# Epoch 376/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 96.9329 - root_mean_squared_error: 97.0048
# Epoch 377/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 96.2643 - root_mean_squared_error: 96.3448
# Epoch 378/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 96.2170 - root_mean_squared_error: 96.2946
# Epoch 379/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 97.5166 - root_mean_squared_error: 97.6086
# Epoch 380/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 95.5151 - root_mean_squared_error: 95.5839
# Epoch 381/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 95.7418 - root_mean_squared_error: 95.8127
# Epoch 382/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 96.8194 - root_mean_squared_error: 96.9225
# Epoch 383/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 95.7297 - root_mean_squared_error: 95.8188
# Epoch 384/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 95.5121 - root_mean_squared_error: 95.5881
# Epoch 385/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 94.6113 - root_mean_squared_error: 94.6731
# Epoch 386/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 95.3467 - root_mean_squared_error: 95.4335
# Epoch 387/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 96.4078 - root_mean_squared_error: 96.4714
# Epoch 388/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 96.0010 - root_mean_squared_error: 96.0581
# Epoch 389/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 95.6722 - root_mean_squared_error: 95.7570
# Epoch 390/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 93.7635 - root_mean_squared_error: 93.8332
# Epoch 391/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 94.5196 - root_mean_squared_error: 94.5866
# Epoch 392/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 94.6760 - root_mean_squared_error: 94.7537
# Epoch 393/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 93.4532 - root_mean_squared_error: 93.5213
# Epoch 394/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 93.9130 - root_mean_squared_error: 93.9764
# Epoch 395/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 93.2404 - root_mean_squared_error: 93.2863
# Epoch 396/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 92.8958 - root_mean_squared_error: 92.9710
# Epoch 397/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 92.8795 - root_mean_squared_error: 92.9491
# Epoch 398/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 93.1215 - root_mean_squared_error: 93.1764
# Epoch 399/2000
# ...
# Epoch 1868/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.9963 - root_mean_squared_error: 49.0406
# Epoch 1869/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.7408 - root_mean_squared_error: 51.8474
# Epoch 1870/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.0203 - root_mean_squared_error: 50.0856
# Epoch 1871/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1340 - root_mean_squared_error: 50.2007
# Epoch 1872/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.4657 - root_mean_squared_error: 51.5668
# Epoch 1873/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 53.5265 - root_mean_squared_error: 53.7249
# Epoch 1874/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.4586 - root_mean_squared_error: 50.5310
# Epoch 1875/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1704 - root_mean_squared_error: 50.2152
# Epoch 1876/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.5586 - root_mean_squared_error: 51.6995
# Epoch 1877/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.3391 - root_mean_squared_error: 49.3859
# Epoch 1878/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.2887 - root_mean_squared_error: 51.4177
# Epoch 1879/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.2303 - root_mean_squared_error: 51.3641
# Epoch 1880/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.7513 - root_mean_squared_error: 50.8504
# Epoch 1881/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.9472 - root_mean_squared_error: 51.0312
# Epoch 1882/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.3328 - root_mean_squared_error: 50.4021
# Epoch 1883/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.3919 - root_mean_squared_error: 50.4959
# Epoch 1884/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1958 - root_mean_squared_error: 50.3113
# Epoch 1885/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.9098 - root_mean_squared_error: 48.9667
# Epoch 1886/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.8178 - root_mean_squared_error: 51.8870
# Epoch 1887/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.4212 - root_mean_squared_error: 49.5043
# Epoch 1888/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.0285 - root_mean_squared_error: 51.2678
# Epoch 1889/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.2220 - root_mean_squared_error: 50.2859
# Epoch 1890/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 54.3271 - root_mean_squared_error: 54.7198
# Epoch 1891/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 49.9696 - root_mean_squared_error: 50.0476
# Epoch 1892/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 49.7593 - root_mean_squared_error: 49.8082
# Epoch 1893/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 51.8885 - root_mean_squared_error: 52.1180
# Epoch 1894/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 49.7411 - root_mean_squared_error: 49.8311
# Epoch 1895/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.8320 - root_mean_squared_error: 50.9177
# Epoch 1896/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.2927 - root_mean_squared_error: 51.4669
# Epoch 1897/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.9071 - root_mean_squared_error: 52.0094
# Epoch 1898/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.9543 - root_mean_squared_error: 51.0381
# Epoch 1899/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.1455 - root_mean_squared_error: 51.2682
# Epoch 1900/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.5099 - root_mean_squared_error: 50.5617
# Epoch 1901/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.3433 - root_mean_squared_error: 49.4019
# Epoch 1902/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.3049 - root_mean_squared_error: 51.4163
# Epoch 1903/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 49.6971 - root_mean_squared_error: 49.7603
# Epoch 1904/2000
# 80/80 [==============================] - 0s 2ms/step - loss: 51.5151 - root_mean_squared_error: 51.5985
# Epoch 1905/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1905 - root_mean_squared_error: 50.2681
# Epoch 1906/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.8663 - root_mean_squared_error: 48.9348
# Epoch 1907/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.6871 - root_mean_squared_error: 50.8348
# Epoch 1908/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 65.4341 - root_mean_squared_error: 65.8110
# Epoch 1909/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 56.8756 - root_mean_squared_error: 57.3487
# Epoch 1910/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.3891 - root_mean_squared_error: 48.4317
# Epoch 1911/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.5006 - root_mean_squared_error: 49.5452
# Epoch 1912/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.6488 - root_mean_squared_error: 49.6894
# Epoch 1913/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.5826 - root_mean_squared_error: 50.6717
# Epoch 1914/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.2087 - root_mean_squared_error: 48.2447
# Epoch 1915/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.8537 - root_mean_squared_error: 48.8996
# Epoch 1916/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.6988 - root_mean_squared_error: 50.7584
# Epoch 1917/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.4300 - root_mean_squared_error: 49.4785
# Epoch 1918/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.7903 - root_mean_squared_error: 49.8461
# Epoch 1919/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.9783 - root_mean_squared_error: 50.0448
# Epoch 1920/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1785 - root_mean_squared_error: 50.2541
# Epoch 1921/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.5587 - root_mean_squared_error: 49.6160
# Epoch 1922/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.4207 - root_mean_squared_error: 49.4741
# Epoch 1923/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1378 - root_mean_squared_error: 50.2266
# Epoch 1924/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.0643 - root_mean_squared_error: 49.1190
# Epoch 1925/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.7901 - root_mean_squared_error: 49.9155
# Epoch 1926/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1783 - root_mean_squared_error: 50.2355
# Epoch 1927/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.4485 - root_mean_squared_error: 49.4959
# Epoch 1928/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.9364 - root_mean_squared_error: 51.0378
# Epoch 1929/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 54.2755 - root_mean_squared_error: 54.5790
# Epoch 1930/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.7888 - root_mean_squared_error: 50.8681
# Epoch 1931/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.4561 - root_mean_squared_error: 49.5266
# Epoch 1932/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.6411 - root_mean_squared_error: 49.6998
# Epoch 1933/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 52.0982 - root_mean_squared_error: 52.1807
# Epoch 1934/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.3564 - root_mean_squared_error: 50.4361
# Epoch 1935/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.7104 - root_mean_squared_error: 49.8133
# Epoch 1936/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.7129 - root_mean_squared_error: 50.8550
# Epoch 1937/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.9467 - root_mean_squared_error: 50.0334
# Epoch 1938/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.5387 - root_mean_squared_error: 49.6126
# Epoch 1939/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.8911 - root_mean_squared_error: 49.9598
# Epoch 1940/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.7971 - root_mean_squared_error: 50.8732
# Epoch 1941/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1148 - root_mean_squared_error: 50.1765
# Epoch 1942/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.5702 - root_mean_squared_error: 50.7011
# Epoch 1943/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.8517 - root_mean_squared_error: 49.9247
# Epoch 1944/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.5169 - root_mean_squared_error: 49.5672
# Epoch 1945/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1766 - root_mean_squared_error: 50.3116
# Epoch 1946/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1514 - root_mean_squared_error: 50.2188
# Epoch 1947/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.6874 - root_mean_squared_error: 49.7594
# Epoch 1948/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.9435 - root_mean_squared_error: 50.0107
# Epoch 1949/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.6366 - root_mean_squared_error: 49.6911
# Epoch 1950/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.9695 - root_mean_squared_error: 51.1119
# Epoch 1951/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.7967 - root_mean_squared_error: 50.8922
# Epoch 1952/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.3859 - root_mean_squared_error: 50.5317
# Epoch 1953/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.7825 - root_mean_squared_error: 49.8505
# Epoch 1954/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.9313 - root_mean_squared_error: 50.0078
# Epoch 1955/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.7015 - root_mean_squared_error: 49.7737
# Epoch 1956/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.3299 - root_mean_squared_error: 50.4084
# Epoch 1957/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.3536 - root_mean_squared_error: 50.4582
# Epoch 1958/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.6810 - root_mean_squared_error: 49.7678
# Epoch 1959/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.8687 - root_mean_squared_error: 51.0515
# Epoch 1960/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.7560 - root_mean_squared_error: 50.8312
# Epoch 1961/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.2927 - root_mean_squared_error: 49.3784
# Epoch 1962/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.8429 - root_mean_squared_error: 48.9069
# Epoch 1963/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.3976 - root_mean_squared_error: 49.5050
# Epoch 1964/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.0554 - root_mean_squared_error: 50.1322
# Epoch 1965/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.6473 - root_mean_squared_error: 49.7092
# Epoch 1966/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.8359 - root_mean_squared_error: 49.9379
# Epoch 1967/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.8041 - root_mean_squared_error: 50.9144
# Epoch 1968/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.8497 - root_mean_squared_error: 49.9679
# Epoch 1969/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.1351 - root_mean_squared_error: 49.1841
# Epoch 1970/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.1461 - root_mean_squared_error: 49.2208
# Epoch 1971/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.7212 - root_mean_squared_error: 50.8147
# Epoch 1972/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.7178 - root_mean_squared_error: 49.7762
# Epoch 1973/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.6024 - root_mean_squared_error: 49.6795
# Epoch 1974/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 52.7028 - root_mean_squared_error: 52.8475
# Epoch 1975/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.7038 - root_mean_squared_error: 50.8161
# Epoch 1976/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.1164 - root_mean_squared_error: 48.1644
# Epoch 1977/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.2926 - root_mean_squared_error: 49.3815
# Epoch 1978/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.1044 - root_mean_squared_error: 49.1517
# Epoch 1979/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.2780 - root_mean_squared_error: 50.4231
# Epoch 1980/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.0256 - root_mean_squared_error: 49.1070
# Epoch 1981/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.0514 - root_mean_squared_error: 50.1357
# Epoch 1982/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.0118 - root_mean_squared_error: 50.1250
# Epoch 1983/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 52.7429 - root_mean_squared_error: 52.9644
# Epoch 1984/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.2536 - root_mean_squared_error: 50.3140
# Epoch 1985/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.6311 - root_mean_squared_error: 49.7064
# Epoch 1986/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 47.8945 - root_mean_squared_error: 47.9345
# Epoch 1987/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 51.6189 - root_mean_squared_error: 51.7578
# Epoch 1988/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.2234 - root_mean_squared_error: 48.2680
# Epoch 1989/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.8817 - root_mean_squared_error: 48.9516
# Epoch 1990/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.9267 - root_mean_squared_error: 48.9832
# Epoch 1991/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.8650 - root_mean_squared_error: 48.9124
# Epoch 1992/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.4181 - root_mean_squared_error: 49.4661
# Epoch 1993/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.0941 - root_mean_squared_error: 49.1637
# Epoch 1994/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.5931 - root_mean_squared_error: 49.6600
# Epoch 1995/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.9818 - root_mean_squared_error: 51.1086
# Epoch 1996/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.8622 - root_mean_squared_error: 48.9280
# Epoch 1997/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 48.5499 - root_mean_squared_error: 48.6004
# Epoch 1998/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 50.1475 - root_mean_squared_error: 50.2350
# Epoch 1999/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 52.4699 - root_mean_squared_error: 52.6277
# Epoch 2000/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 49.3657 - root_mean_squared_error: 49.5132
